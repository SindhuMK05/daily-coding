# %%
import pandas as pd
pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
import pandas as pd
import numpy as np
info=np.array(['a','b','c','d'])
a=pd.Series(info)
print(a)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
color=['red','blue','yellow']#list
df=pd.DataFrame(color)
print(df)
# Out:
#         0
# 0     red
# 1    blue
# 2  yellow

# %%
#dictionary
import pandas as pd
dict_a={'ID':[1,2,3,4],'NAME':['Sindhu','Savita','Vishal','Suman']}
print(dict_a)
df=pd.DataFrame(dict_a)
print(df)
# Out:
# {'ID': [1, 2, 3, 4], 'NAME': ['Sindhu', 'Savita', 'Vishal', 'Suman']}
#    ID    NAME
# 0   1  Sindhu
# 1   2  Savita
# 2   3  Vishal
# 3   4   Suman
# ID           2
# NAME    Savita
# Name: 1, dtype: object

# %%
import pandas as pd
dict_a={'ID':[1,2,3,4],'NAME':['Sindhu','Savita','Vishal','Suman']}
df=pd.DataFrame(dict_a)
print(df.loc[1])

print(df.iloc[[0,2]])

print(df.iloc[0:1])
# Out:
# ID           2
# NAME    Savita
# Name: 1, dtype: object
#    ID    NAME
# 0   1  Sindhu
# 2   3  Vishal
#    ID    NAME
# 0   1  Sindhu

# %%
import pandas as pd
import numpy as np
d1={'ID':[1,2,3,4],'NAME':['Sindhu','Savita','Vishal','Suman']}
df=pd.DataFrame(d1)
d={'ID':[1001],'NAME':['Sindhu']}
df2=pd.DataFrame(d)
df2=df.append(df)
print(df1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5992\1662651662.py in ?()
#       3 d1={'ID':[1,2,3,4],'NAME':['Sindhu','Savita','Vishal','Suman']}
#       4 df=pd.DataFrame(d1)
#       5 d={'ID':[1001],'NAME':['Sindhu']}
#       6 df2=pd.DataFrame(d)
# ----> 7 df=df2.append(df)
#       8 print(df1)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
